# %% [markdown]
# ## This script contains the following:
#
# ### 1. Importing Visualization Libraries and Data
#
# ### 2. Exploring Relationships
#
# Correlations
#
# Scatterplots
#
# Pair Plots
#
# Categorical Plots

# %% [markdown]
# ### 1. Importing Visualization Libraries and Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
pwd
# Out:
# '/Users/milivanili/Desktop/CF Document 6/02 Scripts'

# %%
#Importing dataset
df=pd.read_csv(r'/Users/milivanili/Desktop/CF Document 6/01 Data/Prepared Data/df_wrangled1.csv')
df.head()
# Out:
#    Unnamed: 0      Country Code  Year  Outdoor air pollution  \
# 0           0  Afghanistan  AFG  1990                   3169
# 1           1  Afghanistan  AFG  1991                   3222
# 2           2  Afghanistan  AFG  1992                   3395
# 3           3  Afghanistan  AFG  1993                   3623
# 4           4  Afghanistan  AFG  1994                   3788
#
#    High systolic blood pressure  Diet high in sodium   \
# 0                         25633                  1045
# 1                         25872                  1055
# 2                         26309                  1075
# 3                         26961                  1103
# 4                         27658                  1134
#
#    Diet low in whole grains  Alcohol use  Diet low in fruits  ...  \
# 0                      7077          356                3185  ...
# 1                      7149          364                3248  ...
# 2                      7297          376                3351  ...
# ...

# %%
#Dropping column 'Unnamed:0'
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
#Changing column names for clarification

df.rename(columns={
    "No access to handwashing": "No sanitation access",
    "Diet low in fruits": "Fruits low diet",
    "Diet low in Vegetables": "Vegetables low diet",
    "House air pollution from solid fuels": "Household polluted air"
}, inplace=True)

# %%
df.head()
# Out:
#        Country Code  Year  Outdoor air pollution  \
# 0  Afghanistan  AFG  1990                   3169
# 1  Afghanistan  AFG  1991                   3222
# 2  Afghanistan  AFG  1992                   3395
# 3  Afghanistan  AFG  1993                   3623
# 4  Afghanistan  AFG  1994                   3788
#
#    High systolic blood pressure  Diet high in sodium   \
# 0                         25633                  1045
# 1                         25872                  1055
# 2                         26309                  1075
# 3                         26961                  1103
# 4                         27658                  1134
#
#    Diet low in whole grains  Alcohol use  Fruits low diet  \
# 0                      7077          356             3185
# 1                      7149          364             3248
# 2                      7297          376             3351
# 3                      7499          389             3480
# ...

# %%
 #Check for missing values
missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# Country                                      0
# Code                                        30
# Year                                         0
# Outdoor air pollution                        0
# High systolic blood pressure                 0
# Diet high in sodium                          0
# Diet low in whole grains                     0
# Alcohol use                                  0
# Fruits low diet                              0
# Unsafe water source                          0
# Secondhand smoke                             0
# Low birth weight                             0
# Child wasting                                0
# Unsafe sex                                   0
# Diet low in nuts and seeds                   0
# Household air pollution from solid fuels     0
# Vegetables low diet                          0
# Low physical activity                        0
# Smoking                                      0
# High fasting plasma glucose                  0
# ...

# %%
missing_values= df[df['Code'].isnull() ==True]

# %%
 #Check for missing values
missing_values
# Out:
#                Country Code  Year  Outdoor air pollution  \
# 4020  Northern Ireland  NaN  1990                    828
# 4021  Northern Ireland  NaN  1991                    800
# 4022  Northern Ireland  NaN  1992                    770
# 4023  Northern Ireland  NaN  1993                    772
# 4024  Northern Ireland  NaN  1994                    740
# 4025  Northern Ireland  NaN  1995                    730
# 4026  Northern Ireland  NaN  1996                    694
# 4027  Northern Ireland  NaN  1997                    668
# 4028  Northern Ireland  NaN  1998                    647
# 4029  Northern Ireland  NaN  1999                    638
# 4030  Northern Ireland  NaN  2000                    599
# 4031  Northern Ireland  NaN  2001                    562
# 4032  Northern Ireland  NaN  2002                    557
# 4033  Northern Ireland  NaN  2003                    541
# 4034  Northern Ireland  NaN  2004                    527
# ...

# %%
# Check column names and data types
df.dtypes
# Out:
# Country                                     object
# Code                                        object
# Year                                         int64
# Outdoor air pollution                        int64
# High systolic blood pressure                 int64
# Diet high in sodium                          int64
# Diet low in whole grains                     int64
# Alcohol use                                  int64
# Fruits low diet                              int64
# Unsafe water source                          int64
# Secondhand smoke                             int64
# Low birth weight                             int64
# Child wasting                                int64
# Unsafe sex                                   int64
# Diet low in nuts and seeds                   int64
# Household air pollution from solid fuels     int64
# Vegetables low diet                          int64
# Low physical activity                        int64
# ...

# %%
# Display column names
df.columns
# Out:
# Index(['Country', 'Code', 'Year', 'Outdoor air pollution',
#        'High systolic blood pressure', 'Diet high in sodium ',
#        'Diet low in whole grains', 'Alcohol use', 'Fruits low diet',
#        'Unsafe water source', 'Secondhand smoke', 'Low birth weight',
#        'Child wasting', 'Unsafe sex', 'Diet low in nuts and seeds',
#        'Household air pollution from solid fuels', 'Vegetables low diet',
#        'Low physical activity', 'Smoking', 'High fasting plasma glucose',
#        'Air pollution', 'High body mass index', 'Unsafe sanitation',
#        'No access to handwashing facility', 'Drug use',
#        'Low bone mineral density', 'Vitamin A deficiency',
#        'Child stunted growt', 'Discontinued breastfeeding',
#        'Non-exclusive breastfeeding', 'Iron deficiency', 'Continents',
#        'Decade', 'Environmental Factors', 'Lifestyle Factors',
#        'Health Conditions', 'Maternal and Child Health'],
#       dtype='object')

# %%
# Remove trailing space from the column name
df.rename(columns={'Diet high in sodium ': 'Diet high in sodium'}, inplace=True)

# %% [markdown]
# ### Exploring relationships

# %%
#Create a correlation matrix using pandas
#Select only the numerical columns from the DataFrame to avoid errors
numerical_columns = df.select_dtypes(include=['int', 'float'])

#The index ('rank') is one of the numerical columns, so we will drop it

if 'rank' in numerical_columns.columns:
    numerical_columns = numerical_columns.drop(columns=['rank'])

#Now, we create the correlation matrix with the appropriate data
numerical_columns.corr()
# Out:
#                                               Year  Outdoor air pollution  \
# Year                                      1.000000               0.035777
# Outdoor air pollution                     0.035777               1.000000
# High systolic blood pressure              0.034142               0.955059
# Diet high in sodium                       0.016083               0.924249
# Diet low in whole grains                  0.034488               0.901588
# Alcohol use                               0.027304               0.910201
# Fruits low diet                           0.013509               0.952322
# Unsafe water source                      -0.033793               0.419783
# Secondhand smoke                          0.003259               0.957381
# Low birth weight                         -0.031135               0.490766
# Child wasting                            -0.084941               0.374282
# Unsafe sex                                0.033378               0.327055
# ...

# %%
#Now, we use the above data to create a correlation heatmap using matplotlib

plt.matshow(numerical_columns.corr())
plt.show()

# %%
#Next, we add a legend, column labels, change the size of the heatmap and add a title
f=plt.figure(figsize=(9,9)) #This establishes the size of the heatmap
plt.matshow(numerical_columns.corr(), fignum=f.number) #Defines the type of plot
plt.xticks(range(numerical_columns.shape[1]), numerical_columns.columns, fontsize=12, rotation=90)
plt.yticks(range(numerical_columns.shape[1]), numerical_columns.columns, fontsize=12) #No need for rotation in y-axis
cb=plt.colorbar() #add a color legend (optimizes itseld based on colors used in heatmap)
cb.ax.tick_params(labelsize=12) #add font size
plt.title('Correlation Matrix', fontsize=15) #Creates titles
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(numerical_columns.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# ### The lighter the color, the stronger the (positive) relationship, and vice versa for the darker colors.

# %% [markdown]
# ### Pair plots

# %%
# Recreate the scatter plot for 'Outdoor air pollution' vs. 'High systolic blood pressure'
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Outdoor air pollution', y='High systolic blood pressure')
sns.regplot(data=df, x='Outdoor air pollution', y='High systolic blood pressure', scatter=False, color='lightblue')
plt.title('Outdoor Air Pollution vs. High Systolic Blood Pressure')
plt.xlabel('Outdoor Air Pollution')
plt.ylabel('High Systolic Blood Pressure')
plt.show()

# %%
 #Recreate the scatter plot for 'Diet high in sodium' vs. 'High systolic blood pressure'
# Scatter plot with trend line
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Diet high in sodium', y='High systolic blood pressure')
sns.regplot(data=df, x='Diet high in sodium', y='High systolic blood pressure', scatter=False, color='lightblue')
plt.title('Diet High in Sodium vs. High Systolic Blood Pressure')
plt.xlabel('Diet High in Sodium')
plt.ylabel('High Systolic Blood Pressure')
plt.show()

# %% [markdown]
# #### The scatter plot and trend line show the relationship between "Diet high in sodium" and "High systolic blood pressure, helping us understand if higher sodium intake is linked to higher blood pressure. This is valuable for dietary recommendations.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Alcohol use', y='High systolic blood pressure')
sns.regplot(data=df, x='Alcohol use', y='High systolic blood pressure', scatter=False, color='lightblue')
plt.title('Alcohol Use vs. High Systolic Blood Pressure')
plt.xlabel('Alcohol Use')
plt.ylabel('High Systolic Blood Pressure')
plt.show()

# %% [markdown]
# #### The scatter plot and trend line for 'Alcohol use' vs. 'High systolic blood pressure' suggest a relationship between alcohol consumption and systolic blood pressure, indicating that increased alcohol consumption may be linked to higher systolic blood pressure.

# %%
#Creating a segmented df with the variables being used in the pair plot
sub_df=numerical_columns[['Low physical activity', 'Diet high in sodium','Outdoor air pollution','High systolic blood pressure']]

# %%
labels=['Low physical activity', 'Diet high in sodium','Outdoor air pollution','High systolic blood pressure']
x=sns.pairplot(sub_df)
for ax in x.axes.flatten():
    # rotate x axis labels
    ax.set_xlabel(ax.get_xlabel(), rotation = 45)
    # rotate y axis labels
    ax.set_ylabel(ax.get_ylabel(), rotation = 0)
    # set y labels alignment
    ax.yaxis.get_label().set_horizontalalignment('right')
# Out:
# /Users/milivanili/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/milivanili/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/milivanili/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### Categorical Plot

# %%
# Plotting the box plot for Country and Unsafe water source
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='Country', y='Unsafe water source')
plt.title('Unsafe Water Source by Country')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Unsafe Water Source')
# Out:
# Text(0, 0.5, 'Unsafe Water Source')

# %% [markdown]
# #### It's difficult to identify countries with the most unsafe water sources due to a large list, but India stands out as the country with the least safe water sources.

# %%
# Create bins for Outdoor Air Pollution
df['Outdoor Air Pollution Category'] = pd.cut(df['Outdoor air pollution'], bins=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# Plotting the box plot for Outdoor Air Pollution categorized by Continents
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='Outdoor Air Pollution Category', y='Outdoor air pollution', hue='Continents')
plt.title('Outdoor Air Pollution by Continent')
plt.xlabel('Outdoor Air Pollution Category')
plt.ylabel('Outdoor Air Pollution')
plt.legend(title='Continent')
plt.show()
# Out:
# /Users/milivanili/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /Users/milivanili/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# #### Asia and Africa typically have higher pollution levels (Medium to Very High categories), indicating more significant pollution issues. Oceania and Europe usually have better air quality, falling within the Very Low and Low categories. •Outliers (dots outside the whiskers) indicate regions with unusually high or low pollution levels compared to the overall trend.

# %%
 #Create a contingency table for Continents and Decade
continent_decade = pd.crosstab(df['Continents'], df['Decade'], normalize=True)

# %%
continent_decade
# Out:
# Decade              00s       10s       90s
# Continents
# Africa         0.087805  0.087805  0.087805
# Asia           0.079675  0.079675  0.079675
# Europe         0.069919  0.069919  0.069919
# North America  0.043902  0.043902  0.043902
# Oceania        0.032520  0.032520  0.032520
# South America  0.019512  0.019512  0.019512

# %%
country_totals = df.groupby('Country')['Discontinued breastfeeding'].sum()

# Get the top 10 countries by total discontinued breastfeeding
top_countries = country_totals.nlargest(10)

# Create a bar plot with the top 10 countries
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=top_countries.index, y=top_countries.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Discontinued Breastfeeding')
plt.title('Top 10 Countries by Total Discontinued Breastfeeding')
ab.bar_label(ab.containers[0])
plt.tight_layout()

plt.show()

# %%
# Group by 'Country' and calculate the sum of 'Maternal and Child Health' values
country_health_totals = df.groupby('Country')['Maternal and Child Health'].sum()

# Get the top 10 countries by total Maternal and Child Health
top_countries_health = country_health_totals.nlargest(10)

# Create a bar plot with the top 10 countries
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=top_countries_health.index, y=top_countries_health.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Maternal and Child Health')
plt.title('Top 10 Countries by Total Maternal and Child Health')

plt.tight_layout()

plt.show()

top_countries_health
# Out:
# Country
# India                               41511148
# Nigeria                             17541227
# Pakistan                            11111655
# China                                7704371
# Ethiopia                             6859841
# Bangladesh                           5502093
# Indonesia                            4470703
# Democratic Republic of the Congo     4251555
# Niger                                2534495
# United Republic of Tanzania          2460088
# Name: Maternal and Child Health, dtype: int64

# %%
# Group by 'Country' and calculate the sum of 'Low Birth Weight' values
country_low_birth_weight_totals = df.groupby('Country')['Low birth weight'].sum()

# Get the top 10 countries by total Low Birth Weight
top_countries_low_birth_weight = country_low_birth_weight_totals.nlargest(10)

# Create a bar plot with the top 10 countries
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=top_countries_low_birth_weight.index, y=top_countries_low_birth_weight.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Low birth weight')
plt.title('Top 10 Countries by Total Low birth weight')



plt.tight_layout()
plt.show()

# %%
# Group by 'Country' and calculate the sum of 'Child Stunted Growth' 
country_stunted_growt_totals = df.groupby('Country')['Child stunted growt'].sum()


# Get the top 10 countries by total Child Stunted Growth
country_stunted_growt_totals = country_stunted_growt_totals.nlargest(10)


# Plotting the top 10 countries by Child Stunted Growth
plt.figure(figsize=(10, 6))
ab1 = sns.barplot(x=country_stunted_growt_totals.index, y=country_stunted_growt_totals.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Child Stunted Growt')
plt.title('Country by Total Child stunted growt')
ab.bar_label(ab.containers[0])


plt.tight_layout()
plt.show()

country_stunted_growt_totals
# Out:
# Country
# India                               3458584
# Nigeria                             2301862
# Pakistan                             861620
# Ethiopia                             809564
# China                                546551
# Democratic Republic of the Congo     409676
# Bangladesh                           377844
# Niger                                370600
# Indonesia                            354832
# United Republic of Tanzania          252301
# Name: Child stunted growt, dtype: int64

# %%
country_unsafe_water_totals = df.groupby('Country')['Unsafe water source'].sum()
top_countries_unsafe_water = country_unsafe_water_totals.nlargest(10)

# Plotting the top 10 countries by Unsafe Water Source
plt.figure(figsize=(10, 6))
ab2 = sns.barplot(x=top_countries_unsafe_water.index, y=top_countries_unsafe_water.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Unsafe water source')
plt.title('Top 10 Countries by Total Unsafe Water Source')
ab.bar_label(ab.containers[0])


plt.tight_layout()
plt.show()

# %%
# Group by 'Continent' and calculate the sum of 'Unsafe Water Source' values
continents_unsafe_water_totals = df.groupby('Continents')['Unsafe water source'].sum()



# Create a bar plot with the total Unsafe Water Source by continent
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=continents_unsafe_water_totals.index, y=continents_unsafe_water_totals.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Continents')
plt.ylabel('Total Unsafe water source')
plt.title('Total Unsafe Water Source by Continents')



plt.tight_layout()
plt.show()

continents_unsafe_water_totals
# Out:
# Continents
# Africa           22478563
# Asia             31306990
# Europe              35004
# North America      598955
# Oceania             87080
# South America      600416
# Name: Unsafe water source, dtype: int64

# %%
country_alcohol_use_totals = df.groupby('Country')['Alcohol use'].sum()

# Get the top 10 countries by total Alcohol Use
top_countries_alcohol_use = country_alcohol_use_totals.nlargest(10)


# Create a bar plot with the top 10 countries
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=top_countries_alcohol_use.index, y=top_countries_alcohol_use.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Alcohol Use')
plt.title('Top 10 Countries by Total Alcohol Use')


plt.tight_layout()
plt.show()

# %%
# Group by 'Country' and calculate the sum of 'Alcohol Use' values
last_country_alcohol_use_totals = df.groupby('Country')['Alcohol use'].sum()

# Get the last 10 countries by total Alcohol Use
last_countries_alcohol_use = country_alcohol_use_totals.nsmallest(10)



# Create a bar plot with the last 10 countries
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=last_countries_alcohol_use.index, y=last_countries_alcohol_use.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Total Alcohol Use')
plt.title('Last 10 Countries by Total Alcohol Use')
ab.bar_label(ab.containers[0])

plt.tight_layout()
plt.show()

# %%
continent_alcohol_use_totals = df.groupby('Continents')['Alcohol use'].sum()


# Create a bar plot with the total Alcohol Use by continent
plt.figure(figsize=(10, 6))
ab = sns.barplot(x=continent_alcohol_use_totals.index, y=continent_alcohol_use_totals.values)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Continent')
plt.ylabel('Total Alcohol Use')
plt.title('Total Alcohol Use by Continent')
ab.bar_label(ab.containers[0])

plt.tight_layout()
plt.show()


continent_alcohol_use_totals
# Out:
# Continents
# Africa            6978966
# Asia             28645187
# Europe           18007922
# North America     4996230
# Oceania            258528
# South America     3594290
# Name: Alcohol use, dtype: int64

# %% [markdown]
# ###    Exploring key questions:

# %% [markdown]
# #### 1. how does the prevalence of diets high in sodium and low in fruits, vegetables, or whole grains correlate with cardiovascular disease mortality rates across countries?
#
# China and India, which have high total lifestyle factors, also appear to have high total alcohol use and unsafe water sources, which could contribute to cardiovascular disease mortality rates.

# %% [markdown]
# #### 2. Are there noticeable differences in mortality rates related to dietary behaviours across regions with different dietary traditions?
# Asia and Africa show high totals in unsafe water sources and low birth weight. Europe and North America have significant alcohol use. These differences suggest that regions with different dietary traditions and access to resources exhibit varying health outcomes.

# %% [markdown]
# #### 3. How do infant mortality rates and low birth weight statistics correlate with access to clean water and sanitation facilities?
# India and Nigeria have high totals of unsafe water sources and low birth weight, indicating a possible correlation. Regions with poor water quality, such as Africa and Asia, also show higher low birth weight statistics.

# %% [markdown]
# #### 4. What is the impact of discontinued breastfeeding and non-exclusive breastfeeding on child stunting and mortality rates in different countries?
# High infant mortality rates and discontinued breastfeeding are prevalent in Africa and Asia. Countries in these regions likely experience higher child stunting and mortality rates due to discontinued or non-exclusive breastfeeding practices.

# %% [markdown]
# #### 5.Prevalence of unsafe sanitation impact on overall life expectancy and disease prevalence in various regions:
# High levels of unsafe water sources in Africa and Asia

# %% [markdown]
# #### 6.Trends in alcohol and drug use over the past decade across different countries:
# Significant alcohol use in Asia and Europe, with increasing trends in some regions. Oceania has very low alcohol use, indicating varied trends across different continents.

# %%
df.to_csv(r'/Users/milivanili/Desktop/CF Document 6/01 Data/Prepared Data/df_relation.csv')
